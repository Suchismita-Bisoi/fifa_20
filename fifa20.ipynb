# %% [markdown]
# # **Data Science Project On Clustering FIFA 20 dataset**

# %% [markdown]
# # *Business Task* : Clustering the football players of the most popular sport in the world and FIFA is the most popular football

# %% [markdown]
# ## *Task* : Clustering

# %% [markdown]
# ## *Necessary Library*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading dataset

# %%
data = pd.read_csv("players_20.csv")
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %% [markdown]
# ## *Domain Analysis*

# %% [markdown]
# ### Introduction

# %% [markdown]
# The dataset includes the players data for the Career Mode from FIFA 15 to FIFA 20. The dataset contains 18277 rows and 104 columns.We have to cluster the data on the basic of attributes.

# %% [markdown]
# #### **sofifa_id**:
#
# It s says the players id in the dataset

# %% [markdown]
# #### **player_url :**
#
# Its shows the web address of the players

# %% [markdown]
# #### **short_name :**
#
# This column represents short name of the player

# %% [markdown]
# #### **long_name :**
#
# Its shows the full name of the players.

# %% [markdown]
# #### **long_name :**
#
# Its shows the age of the players mentioned in the data

# %% [markdown]
# #### **dob :**
#
# Its shows the date of birth of the players

# %% [markdown]
# #### **height_cm :**
#
# Its shows the height of the players in cm.

# %% [markdown]
# #### **weight_kg :**
#
# Its shows the weight of the players.

# %% [markdown]
# #### **nationality :**
#
# This column represenets the player belongs to which country.

# %% [markdown]
# #### **club :**
#
# Its represent the players coming from which club

# %% [markdown]
# #### **Overall :**
#
# The Overall is made up of all the player's ingame stats.

# %% [markdown]
# #### **Potential :**
#
# they will achieve for sure during the FIFA 20 career mode.

# %% [markdown]
# #### **Value EUR**
#
# The value of player in euro

# %% [markdown]
# #### **Wage EUR**
#
# A living wage is the amount of income needed to provide an player with a basic but socially acceptable standard of living.

# %% [markdown]
# #### **Player Position :**
#
# Positions indicate where each player should be start of a play.

# %% [markdown]
# #### **PREFEERED FOOT :**
#
# The foot a player uses to kick with the greatest force and skill.

# %% [markdown]
# #### **International Reputation :**
#
# It rates within 1-5 stars.

# %% [markdown]
# #### **Weak Foot :**
#
# specifies the shot power and ball control for the other foot of that player than his preferred foot's its rates within 1-5 rates.

# %% [markdown]
# #### **Skill moves:**
#
# Players with higher skills are able to perform more complex moves.

# %% [markdown]
# #### **Work rate :**
#
# Its show how the player perform.

# %% [markdown]
# #### **Body_Type :**
#
# This column shows how the player have their body shape.

# %% [markdown]
# #### **Real_face :**
#
# It will scan thwe photo players then say yes or no.

# %% [markdown]
# #### **Release clause eur :**
#
# A release clause is the minimum amount of money you're willing to accept for that player

# %% [markdown]
# #### **Player_tag :**
#
# It shows what the player are tag with i.e Dribbler, Distance shooter, Crosser, Speedster etc.

# %% [markdown]
# #### **Team_position :**
#
# The player’s positioning on the field

# %% [markdown]
# #### **Team_Jersey_number :**
#
# The number on the back of a football player's jersey is to identify a specific player.

# %% [markdown]
# #### **Loned_from :**
#
# It's a temporary restriction placed on player

# %% [markdown]
# #### **Joined :**
#
# Its show when players join

# %% [markdown]
# #### **Contract_valid_untill :**
#
# The end year of contract of players.

# %% [markdown]
# #### **National_position :**
#
# Nation position is the team position of players.

# %% [markdown]
# #### **National_jersey_number :**
#
# Its shows the jersey number of the player

# %% [markdown]
# #### **Pace :**
#
# Fastest pace of player,striker or winger

# %% [markdown]
# #### **Shoooting :**
#
# shooting is hitting the ball in an attempt to score a goal

# %% [markdown]
# #### **passing :**
#
# The purpose of passing is to keep possession of the ball by maneuvering it on the ground between different players with the objective of advancing it up the playing field.

# %% [markdown]
# #### **Dribbling :**
#
# Dribbling is maneuvering a Ball By One Player While Moving In A Given Direction.

# %% [markdown]
# #### **defending :**
#
# Defending is most relate to the defender to stop the attack

# %% [markdown]
# #### **Physic :**
#
# intensity and their effort

# %% [markdown]
# #### **gk_diving :**
#
# Goal keeper diving to save a shot.

# %% [markdown]
# #### **gk_handling :**
#
# Handling the ball with your hands within your penalty area.

# %% [markdown]
# #### **gk_kicking :**
#
# kicks the ball to play, and they either kick it short to a teammate or it is kicked extremely hard to travel a long distance.

# %% [markdown]
# #### **gk_reflexes :**
#
# ability of reacting.

# %% [markdown]
# #### **gk_speed :**
#
# speed of the goal keeper.

# %% [markdown]
# #### **gk_positioning :**
#
# It show sthe postiton of the goal keeper.

# %% [markdown]
# #### **player_traits :**
#
# It shows which player best on which part.

# %% [markdown]
# #### **attacking_crossing :**
#
# it shows the attacking for the goal.

# %% [markdown]
# #### **attacking_finishing :**
#
# attack on field to score a goal

# %% [markdown]
# #### **attacking_heading_accuracy :**
#
# fundamental principles of the attacking header is to head the ball downwards.

# %% [markdown]
# #### **attacking_short_passing :**
#
# Player’s accuracy for short passes rated between 1-99.

# %% [markdown]
# #### **attacking_volleys :**
#
# Player’s ability to perform volleys rated between 1-99.

# %% [markdown]
# #### **skill_dribbling :**
#
# Dribbling skill of the player rated between 1-99. Dribbling is carrying the ball without losing while moving in one particular direction.

# %% [markdown]
# #### **skill_curve :**
#
# Player’s ability to curve the ball while passing or shooting rated between 1-99

# %% [markdown]
# #### **skill_fk_accuracy :**
#
# ●	FKAccuracy: Player’s accuracy to score free kick goals rated between 1-99.

# %% [markdown]
# #### **skill_long_passing :**
#
# Player’s accuracy for long passes rated between 1-99.

# %% [markdown]
# #### **skill_ball_control :**
#
# Player’s ability to control the ball rated between 1-99.

# %% [markdown]
# #### **movement_acceleration :**
#
# how quickly player can increase your velocity towards maximum speed.

# %% [markdown]
# #### **movement_sprint_speed :**
#
# Sprinting speed score of the player.

# %% [markdown]
# #### **movement_agility :**
#
# Agility is the ability to move quickly and easily, including moving in different directions without losing balance

# %% [markdown]
# #### **movement_reactions :**
#
# The score of the quick reation of player.

# %% [markdown]
# #### **movement_balance :**
#
# Balance is the ability to control your body in its own space.

# %% [markdown]
# #### **power_shot_power :**
#
# power generate to score a goal.

# %% [markdown]
# #### **power_jumping :**
#
# Player’s jumping skill rated between 1-99.

# %% [markdown]
# #### **power_stamina :**
#
# Physical stamina of the player rated between 1-99.

# %% [markdown]
# #### **power_strength :**
#
# Physical strength of the player rated between 1-99.

# %% [markdown]
# #### **power_long_shots :**
#
# Player’s accuracy of shoots from long distances rated between 1-99.

# %% [markdown]
# #### **mentality_aggression :**
#
# Aggression level of the player while pushing, pulling and tackling rated between 1-99.

# %% [markdown]
# #### **mentality_interceptions :**
#
# Player’s ability to intercept the ball while opposite team’s players are passing rated between 1-99. It is a defensive skill

# %% [markdown]
# #### **mentality_positioning :**
#
# Player’s ability to place himself in the right position to receive the ball or score goals rated between 1-99.

# %% [markdown]
# #### **mentality_vision :**
#
# Player’s mental awareness about the other players in the team for passing rated between 1-99.

# %% [markdown]
# #### **mentality_penalties :**
#
# Player’s accuracy to score goals from penalty rated between 1-99.

# %% [markdown]
# #### **mentality_composure :**
#
# Player’s ability to control his calmness and frustration during the match rated between 1-99.

# %% [markdown]
# #### **defending_marking :**
#
# Player’s ability to apply strategies to prevent opposing team from taking the ball rated between 1-99

# %% [markdown]
# #### **defending_standing_tackle :**
#
# Player’s ability to perform tackle while standing rated between 1-99. It is a defensive skill.

# %% [markdown]
# #### **defending_sliding_tackle :**
#
# Player’s ability to perform tackle by sliding rated between 1-99. It is a defensive skill.

# %% [markdown]
# #### **goalkeeping_diving :**
#
# Goal keeper diving to save a goal.

# %% [markdown]
# #### **goalkeeping_handling :**
#
# handling the ball in penelty area.

# %% [markdown]
# #### **goalkeeping_kicking :**
#
# the attacking team has kicked the ball over the goal line.

# %% [markdown]
# #### **goalkeeping_positioning :**
#
# position of gola keeper.

# %% [markdown]
# #### **goalkeeping_reflexes :**
#
# The reflex of goalkeeper and players

# %% [markdown]
# #### **lS :**
#
# left striker
# Player’s general ability when playing in in LS position rated between 1-99.

# %% [markdown]
# #### **ST :**
#
# Striker
# Player’s general ability when playing in ST position rated between 1-99

# %% [markdown]
# #### **LW :**
#
# Left side Wingers
# Player’s general ability when playing in in LW position rated between 1-99

# %% [markdown]
# #### **LF :**
#
# Left forword

# %% [markdown]
# #### **CF :**
#
# Center forword

# %% [markdown]
# #### **RF :**
#
# Right forword

# %% [markdown]
# #### **RW :**
#
# Right wingers

# %% [markdown]
# #### **lAM :**
# Left attacking midfield

# %% [markdown]
# #### **RAM :**
#
# Center attacking midfield

# %% [markdown]
# #### **CAM :**
#
# Right attacking midfield

# %% [markdown]
# #### **LM :**
#
# Left midfield

# %% [markdown]
# #### **LCM :**
#
# Left center midfield

# %% [markdown]
# #### **CM :**
#
# Center Midfield

# %% [markdown]
# #### **RCM :**
#
# Right center midfield

# %% [markdown]
# #### **RM :**
#
# Right midfield

# %% [markdown]
# #### **LWB :**
#
# Left Wing Back

# %% [markdown]
# #### **LDM :**
#
# Left defensive midfield

# %% [markdown]
# #### **CDM :**
#
# Center defensive midfield

# %% [markdown]
# #### **RDM :**
#
# Right defensive midfield

# %% [markdown]
# #### **RWD :**
#
# Right wing back

# %% [markdown]
# #### **LB :**
#
# Left back

# %% [markdown]
# #### **LCB :**
#
# Left center back

# %% [markdown]
# #### **CB :**
#
# Center back

# %% [markdown]
# #### **RCB :**
#
# Right center back

# %% [markdown]
# #### **RB :**
#
# Right back

# %% [markdown]
# ## *basic checks*

# %%
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
data.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %% [markdown]
# ### Examine the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %% [markdown]
# ### Statistical measure of data

# %%
data.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
data.describe(include = 'O')
# Out:
#                                                player_url    short_name  \
# count                                               18278         18278
# unique                                              18278         17354
# top     https://sofifa.com/player/233449/ximing-pan/20...  J. Rodríguez
# freq                                                    1            11
#
#          long_name         dob nationality            club player_positions  \
# count        18278       18278       18278           18278            18278
# unique       18218        6142         162             698              643
# top     Liam Kelly  1992-02-29     England  Crystal Palace               CB
# freq             3         113        1667              33             2322
#
#        preferred_foot      work_rate body_type  ...    lwb    ldm    cdm  \
# count           18278          18278     18278  ...  16242  16242  16242
# unique              2              9        10  ...     98     98     98
# ...

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
data.shape
# Out:
# (18278, 104)

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Removing Special Character

# %%
# First remove the special character from data
data = data.replace('[\#]','',regex=True)
data.head(1)
# Out:
#    sofifa_id                                         player_url short_name  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
#
#                         long_name  age         dob  height_cm  weight_kg  \
# 0  Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
#
#   nationality          club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 0   Argentina  FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2  52+2
#
#      cb   rcb    rb
# 0  52+2  52+2  63+2
#
# [1 rows x 104 columns]

# %%
# Split the column and remove the '+' with the values after them
columns = ['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm',
           'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']
data[columns]

for colmun in columns:
    data[colmun] = data[colmun].str.split('+',expand=True)[0]
data.head(1)
# Out:
#    sofifa_id                                         player_url short_name  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...   L. Messi
#
#                         long_name  age         dob  height_cm  weight_kg  \
# 0  Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
#
#   nationality          club  ...  lwb  ldm  cdm  rdm rwb  lb  lcb  cb  rcb  rb
# 0   Argentina  FC Barcelona  ...   68   66   66   66  68  63   52  52   52  63
#
# [1 rows x 104 columns]

# %% [markdown]
# ### Univariate Analysis

# %%
# !pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 85.1 MB/s eta 0:00:00
# ...

# %%
univariate = data[[ 'age',  'height_cm', 'weight_kg','overall', 'potential', 'value_eur', 'wage_eur',
                   'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type',
                   'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number',
                   'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing',
                   'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
                   'gk_positioning','attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy',
                   'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy',
                   'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
                   'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping',
                   'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
                   'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking',
                   'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling',
                   'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'ls', 'st', 'rs', 'lw', 'lf',
                   'cf', 'rf', 'rw', 'lam','cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb',
                   'lb', 'lcb', 'cb', 'rcb', 'rb']]
import sweetviz
sv = sweetviz.analyze(univariate)
sv.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### 1.Age to movement reaction

# %%
plt.figure(figsize=(7,5))
sns.set_style('whitegrid')
sns.lineplot(x='age',y='movement_reactions',data=data,color='blue')
plt.show()

# %% [markdown]
# * As much as the age of the player increase the movement of reaction also increases.

# %%
sns.relplot(x='height_cm',y='weight_kg',data=data,color='brown')
plt.show()

# %% [markdown]
# * height increase with respect to increase in weight.

# %% [markdown]
# #### Relation Between pace and shooting w.r.t to preffered foot

# %%
sns.lineplot(x='pace',y='shooting',data=data,color='brown',hue='preferred_foot')
plt.show()

# %% [markdown]
# when the player preferred left foot then the pace is less but shooting is around 50 to 60 and when the player preferred right foot then the pace is less as well as shooting also less.

# %% [markdown]
# ### Imapct of dribbling to defending

# %%
sns.lineplot(x='dribbling',y='defending',data=data,color='cyan')
plt.show()

# %% [markdown]
# ### Imapct of physic to attacking crossing

# %%
sns.lineplot(x='physic',y='attacking_crossing',data=data,color='brown')
plt.show()

# %% [markdown]
# If the physic is less then the attacking crossing is more.
# Otherwise physic range between 35 to 80 the attacking crossing is constant

# %% [markdown]
# ### Imapct of attacking short passing to attacking volleys

# %%
sns.lineplot(x='attacking_short_passing',y='attacking_volleys',data=data,color='brown')
plt.show()

# %% [markdown]
# ## Import Of skill dribbling to skill ball

# %%
sns.lineplot(x='skill_dribbling',y='skill_ball_control',data=data,color='brown')
plt.show()

# %% [markdown]
# ### Relation between skill curve and skill fk accuracy with respect to prefered foot

# %%
sns.lineplot(x='skill_curve',y='skill_fk_accuracy',data=data,color='brown',hue='preferred_foot')
plt.show()

# %% [markdown]
# ### Impact of skill long passing to power long shots

# %%
sns.lineplot(x='skill_long_passing',y='power_long_shots',data=data,color='brown')
plt.show()

# %% [markdown]
# ## Impact of movement sprint speed to movement reaction

# %%
sns.lineplot(x='movement_sprint_speed',y='movement_reactions',data=data,color='brown')
plt.show()

# %% [markdown]
# ## Impact of power shot to power stamina

# %%
sns.lineplot(x='power_shot_power',y='power_stamina',data=data,color='blue')
plt.show()

# %% [markdown]
# ## CATEGORICAL VERIABLE

# %% [markdown]
# #### Impact of work rate to skill moves

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='work_rate',y='skill_moves',data=data)
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# #### Impact of team position to shooting

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='team_position',y='shooting',data=data)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Impact of prefeered foot to pace

# %%
sns.barplot(x='preferred_foot',y='pace',data=data)
plt.show()

# %% [markdown]
# ## Task-3

# %% [markdown]
#  ### 1. Prepare a rank ordered list of top 10 countries with most players. Which countries are producing the most footballers that play at this level?

# %%
country_counts = data['nationality'].value_counts().head(10)

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='nationality',data=data.head(10),palette='CMRmap')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.xticks(rotation=45) # used to tild the name on x axis
plt.title('Which Country are producing players in Top 10?',fontsize = 20)
plt.show()

# %% [markdown]
# * From the above we observe that Belgium produce more football player.

# %% [markdown]
#  ### 2. distribution of overall rating vs. age of players

# %%
plt.figure(figsize=(10, 6))
sns.relplot(x='age', y='overall', data=data)
plt.title('overall vs. age')
plt.show()

# %% [markdown]
# * Overall Rating peaks between 25-28 years old.
# * Players' Overall Rating increases rapidly until 25 years old.
# * Overall Rating declines gradually after 28 years old.
# * Few players maintain high Overall Rating beyond 32 years old.
# * Most players (60%) are between 22-28 years old.
# * Young players (18-21 years old) comprise 20% of the population.
# * Experienced players (29-32 years old) make up 15%.
# * Veterans (33+ years old) account for 5%.

# %% [markdown]
# ### 3.Which type of offensive players tends to get paid the most: the striker, the right-winger, or the left-winger?

# %%
offensive_positions = ['ST', 'RW', 'LW']
offensive_data = data[data['player_positions'].isin(offensive_positions)]

avg_wage_by_position = offensive_data.groupby('player_positions')['wage_eur'].mean().reset_index()

avg_wage_by_position = avg_wage_by_position.sort_values(by='wage_eur', ascending=False)

print("Average Wage by Offensive Player Type:")
print(avg_wage_by_position)
# Out:
# Average Wage by Offensive Player Type:
#   player_positions      wage_eur
# 2               ST  10256.495301
# 0               LW   9681.818182
# 1               RW   6208.791209

# %%
# Plot bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='player_positions', y='wage_eur', data=avg_wage_by_position)
plt.title('Average Wage by Offensive Player Type')
plt.xlabel('Position')
plt.ylabel('Average Wage')
plt.show()

# %% [markdown]
# * The striker offensive players tends to get paid the most from the striker, the right-winger, or the left-winger.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## 1. Checkig missing value

# %%
pd.set_option('display.max_rows',None)
data.isnull().sum()
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club                              0
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur             1298
# player_tags                   16779
# team_position                   240
# team_jersey_number              240
# ...

# %%
def missing_value(data):
    null_value = data.isnull().sum()
    percentage = (data.isnull().sum()/data.isnull().count()*100)
    null_value = pd.concat([null_value,percentage],axis=1,keys=['Missing Number','Missing Percentage'])
    return null_value
missing_value(data)
# Out:
#                             Missing Number  Missing Percentage
# sofifa_id                                0            0.000000
# player_url                               0            0.000000
# short_name                               0            0.000000
# long_name                                0            0.000000
# age                                      0            0.000000
# dob                                      0            0.000000
# height_cm                                0            0.000000
# weight_kg                                0            0.000000
# nationality                              0            0.000000
# club                                     0            0.000000
# overall                                  0            0.000000
# potential                                0            0.000000
# value_eur                                0            0.000000
# wage_eur                                 0            0.000000
# ...

# %% [markdown]
# * 11 feature has more than 50% t0 90% missing value and some contain unique values, so we wull drop the column
#
# * Some other have less than 15% missing value that case wee use median for our missing value

# %% [markdown]
# ## 2.Imputation of missing value

# %%
data['release_clause_eur'].median()
# Out:
# 1200000.0

# %%
data.loc[(data["release_clause_eur"].isnull() == True , "release_clause_eur")] = 1200000.0

# %%
data['team_position'].mode()

#data.loc[(data["release_clause_eur"].isnull() == True , "release_clause_eur")]
# Out:
# 0    SUB
# Name: team_position, dtype: object

# %%
data.loc[(data["team_position"].isnull() == True , "team_position")] = 'SUB'

# %%
data['team_jersey_number'].median()
# Out:
# 17.0

# %%
data.loc[(data["team_jersey_number"].isnull() == True , "team_jersey_number")] = 17

# %%
data['pace'].median()
# Out:
# 69.0

# %%
data.loc[(data["pace"].isnull() == True , "pace")] = 69

# %%
data['shooting'].median()
# Out:
# 54.0

# %%
data.loc[(data["shooting"].isnull() == True , "shooting")] = 54

# %%
data['dribbling'].median()
# Out:
# 64.0

# %%
data.loc[(data["dribbling"].isnull() == True , "dribbling")] = 64

# %%
data['defending'].median()
# Out:
# 56.0

# %%
data.loc[(data["defending"].isnull() == True , "defending")] = 56

# %%
data['physic'].median()
# Out:
# 66.0

# %%
data.loc[(data["physic"].isnull() == True , "physic")] = 66

# %% [markdown]
# ## 3. Handling categorical column

# %% [markdown]
# #### preferred_foot

# %%
data.preferred_foot.value_counts()
# Out:
# preferred_foot
# Right    13960
# Left      4318
# Name: count, dtype: int64

# %%
data.preferred_foot = data.preferred_foot.map({'Right':1,'Left':0})

# %% [markdown]
# #### team_position

# %%
data.team_position.value_counts()
# Out:
# team_position
# SUB    8060
# RES    2958
# GK      662
# RCB     660
# LCB     660
# LB      560
# RB      560
# ST      458
# RCM     411
# LCM     411
# RM      399
# LM      398
# CAM     311
# RDM     244
# LDM     242
# RS      195
# LS      195
# CDM     181
# LW      162
# RW      161
# CB      100
# CM       76
# LWB      58
# RWB      58
# RAM      23
# LAM      23
# RF       19
# LF       19
# CF       14
# Name: count, dtype: int64

# %%
data.team_position = data.team_position.map({'SUB':28,'RES':27,'GK':26,'RCB':25,'LCB':24,'RB':23,'LB':22,'ST':21,
                                            'RCM':20,'LCM':19,'RM':18,'LM':17,'CAM':16,'RDM':15,'LDM':14,'RS':13,
                                            'LS':12,'CDM':11,'LW':10,'RW':9,'CB':8,'CM':7,'RWB':6,'LWB':5,'RAM':4,
                                            'LAM':3,'RF':2,'LF':1,'CF':0})

# %% [markdown]
# * here we use the above two column because all other are unique columns

# %% [markdown]
# ## Feature scalling

# %% [markdown]
# #### MinMax Scalar

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() # Object Creation
data[['age','height_cm','weight_kg','overall','potential','value_eur','wage_eur','release_clause_eur',
    'pace','shooting','passing','dribbling','defending','physic','attacking_crossing','attacking_crossing',
    'attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys',
    'skill_dribbling','skill_curve','skill_fk_accuracy','skill_fk_accuracy','skill_long_passing',
    'skill_ball_control','skill_ball_control','movement_acceleration','movement_sprint_speed',
    'movement_agility','movement_reactions','movement_balance','power_shot_power','power_jumping',
    'power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions',
    'mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking',
    'defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving','goalkeeping_handling',
    'goalkeeping_kicking','goalkeeping_positioning',
    'goalkeeping_reflexes']]=scaler.fit_transform(data[['age','height_cm','weight_kg','overall','potential',
                'value_eur','wage_eur','release_clause_eur','pace','shooting','passing','dribbling','defending',
                'physic','attacking_crossing','attacking_crossing','attacking_finishing','attacking_heading_accuracy',
                'attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy',
                'skill_fk_accuracy','skill_long_passing','skill_ball_control','skill_ball_control','movement_acceleration',
                'movement_sprint_speed','movement_agility','movement_reactions','movement_balance',
                'power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression',
                'mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties',
                'mentality_composure','defending_marking','defending_standing_tackle','defending_sliding_tackle',
                'goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes']])

# %%
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name       age  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini  0.615385
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  0.692308
# 2          Neymar Jr        Neymar da Silva Santos Junior  0.423077
# 3           J. Oblak                            Jan Oblak  0.384615
# 4          E. Hazard                          Eden Hazard  0.461538
#
#           dob  height_cm  weight_kg nationality                 club  ...  \
# 0  1987-06-24   0.285714   0.366667   Argentina         FC Barcelona  ...
# ...

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Drop unique and constant column

# %%
data.drop(['sofifa_id','player_url','short_name','long_name','dob','nationality','club','player_positions','body_type',
          'real_face','player_tags','team_jersey_number','loaned_from','joined','contract_valid_until','nation_position',
          'nation_jersey_number','gk_diving','gk_handling','gk_kicking','gk_reflexes','gk_speed','gk_positioning',
          'player_traits','ls','st','rs','lw','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm',
          'cdm','rdm','rwb','lb','lcb','cb','rcb','rb','lf','work_rate'],axis=1,inplace=True)

# %%
data.head()
# Out:
#         age  height_cm  weight_kg   overall  potential  value_eur  wage_eur  \
# 0  0.615385   0.285714   0.366667  1.000000   0.978261   0.905213  1.000000
# 1  0.692308   0.632653   0.550000  0.978261   0.956522   0.554502  0.716814
# 2  0.423077   0.387755   0.300000  0.956522   0.934783   1.000000  0.513274
# 3  0.384615   0.653061   0.616667  0.934783   0.956522   0.734597  0.221239
# 4  0.461538   0.387755   0.400000  0.934783   0.913043   0.853081  0.831858
#
#    preferred_foot  international_reputation  weak_foot  ...  \
# 0               0                         5          4  ...
# 1               1                         5          4  ...
# 2               1                         5          5  ...
# 3               1                         3          3  ...
# 4               1                         4          4  ...
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0             0.800000             1.000000           0.344086
# ...

# %% [markdown]
# ## Checking correlation

# %%
data.corr()
# Out:
#                                  age  height_cm  weight_kg   overall  \
# age                         1.000000   0.081391   0.237169  0.464305
# height_cm                   0.081391   1.000000   0.768816  0.039945
# weight_kg                   0.237169   0.768816   1.000000  0.156522
# overall                     0.464305   0.039945   0.156522  1.000000
# potential                  -0.262872  -0.002432  -0.011738  0.646650
# value_eur                   0.081513   0.009527   0.051782  0.638230
# wage_eur                    0.151031   0.019547   0.065946  0.573578
# preferred_foot              0.006451   0.083072   0.077787 -0.034474
# international_reputation    0.259582   0.037935   0.090854  0.475557
# weak_foot                   0.073988  -0.175200  -0.128568  0.230276
# skill_moves                 0.045277  -0.429980  -0.352060  0.401261
# release_clause_eur          0.067178   0.010800   0.047365  0.609801
# team_position              -0.161463   0.117796   0.067165 -0.275812
# ...

# %%
plt.figure(figsize =(30,30))
sns.heatmap(data.corr(),annot = True ,cmap = 'coolwarm' )
plt.show()

# %% [markdown]
# #### Checking for duplicate

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.dropna()

# %% [markdown]
# ### Principle Component Analysis

# %%
from sklearn.decomposition import PCA
pca = PCA() # Object creation
principlecomponents = pca.fit_transform(data) # Fitting the data
plt.figure(figsize=(10,7))
sns.set_style('darkgrid')
plt.plot(np.cumsum(pca.explained_variance_ratio_),marker='^') #plot the variance ratio
plt.xlabel('Number of components',fontsize=20)
plt.ylabel('Variance(%)',fontsize=20) # for each componant
plt.title('Explained Variance',fontsize=20)
plt.show()

# %% [markdown]
# * Here we choose 10 component for PCA

# %%
pca = PCA(n_components=10)
pca_data = pca.fit_transform(data)

principle_df = pd.DataFrame(data=pca_data,columns=['pca1','pca2','pca3','pca4','pca5','pca6','pca7','pca8','pca9','pca10'])
principle_df.head()
# Out:
#         pca1      pca2      pca3      pca4      pca5      pca6      pca7  \
# 0 -15.072699  2.680614 -0.420298  1.470804  0.036519  2.692516  1.443779
# 1 -14.094057  3.178045 -0.461398  1.414922  1.119819  2.190821  1.927297
# 2  -8.110916  3.983342  0.253290  1.224380  0.763704  1.957093  2.042541
# 3 -14.056307  2.423135 -0.112987  0.870759  0.745589  1.736942  1.110572
# 4  -4.080370  3.114537  0.808928  1.717493  0.557636  1.520186  1.016147
#
#        pca8      pca9     pca10
# 0  1.419953  0.267281 -0.100231
# 1  0.716721  0.613399  0.125863
# 2  1.342127  0.227329 -0.115909
# 3  1.170764  0.311263 -0.214831
# 4  0.906264  0.101115 -0.242172

# %% [markdown]
# # Model Creation

# %% [markdown]
# KMeans Clustering

# %% [markdown]
# Get best sillhoutte score, range of sillhoutte score between -1 to +1

# %%
X = principle_df
X.head()
# Out:
#         pca1      pca2      pca3      pca4      pca5      pca6      pca7  \
# 0 -15.072699  2.680614 -0.420298  1.470804  0.036519  2.692516  1.443779
# 1 -14.094057  3.178045 -0.461398  1.414922  1.119819  2.190821  1.927297
# 2  -8.110916  3.983342  0.253290  1.224380  0.763704  1.957093  2.042541
# 3 -14.056307  2.423135 -0.112987  0.870759  0.745589  1.736942  1.110572
# 4  -4.080370  3.114537  0.808928  1.717493  0.557636  1.520186  1.016147
#
#        pca8      pca9     pca10
# 0  1.419953  0.267281 -0.100231
# 1  0.716721  0.613399  0.125863
# 2  1.342127  0.227329 -0.115909
# 3  1.170764  0.311263 -0.214831
# 4  0.906264  0.101115 -0.242172

# %%
from sklearn.cluster import KMeans
kmeans = KMeans() # Object creation
wcss = [] # Create empty list

for i in range(2,11):
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans = kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(10,7))
plt.plot(range(2,11),wcss,marker='*')
plt.title('The Elbow Method',fontsize=20)
plt.xlabel('Number of clusters',fontsize=20)
plt.ylabel('WCSS',fontsize=20)
plt.show()

# %% [markdown]
# * From above plot we are select 3 cluster because of odd no and more variance

# %%
kmeans = KMeans(n_clusters=3,random_state=45)


kmeans.fit(X)

kmeans.labels_

# Print dataset with labels
principle_df['cluster'] = pd.DataFrame(kmeans.labels_)
principle_df.head()
# Out:
#         pca1      pca2      pca3      pca4      pca5      pca6      pca7  \
# 0 -15.072699  2.680614 -0.420298  1.470804  0.036519  2.692516  1.443779
# 1 -14.094057  3.178045 -0.461398  1.414922  1.119819  2.190821  1.927297
# 2  -8.110916  3.983342  0.253290  1.224380  0.763704  1.957093  2.042541
# 3 -14.056307  2.423135 -0.112987  0.870759  0.745589  1.736942  1.110572
# 4  -4.080370  3.114537  0.808928  1.717493  0.557636  1.520186  1.016147
#
#        pca8      pca9     pca10  cluster
# 0  1.419953  0.267281 -0.100231        2
# 1  0.716721  0.613399  0.125863        2
# 2  1.342127  0.227329 -0.115909        1
# 3  1.170764  0.311263 -0.214831        2
# 4  0.906264  0.101115 -0.242172        1

# %%
# fro centroids
kmeans.cluster_centers_
# Out:
# array([[ 3.41606854e+00, -5.10535892e-02,  1.29054146e-02,
#         -1.21434030e-02,  5.34772060e-03,  7.74213901e-03,
#          1.85965160e-02, -7.91557590e-03, -6.72178639e-03,
#         -5.82654213e-03],
#        [-4.06164912e+00,  2.37157252e-01, -6.09590829e-02,
#          6.02364024e-02, -3.96186857e-02, -3.98568223e-02,
#         -6.27954254e-02,  3.45575775e-02,  2.66248834e-02,
#          2.56747191e-02],
#        [-1.31104578e+01, -1.53783101e-01,  4.08754220e-02,
#         -4.41632934e-02,  4.53954467e-02,  3.10355483e-02,
#          9.26223188e-03, -1.94585355e-02, -1.11313136e-02,
#         -1.47936197e-02]])

# %% [markdown]
# # Model Evalution

# %%
from sklearn.metrics import silhouette_score
silho_score = silhouette_score(X,kmeans.labels_)
print("silhouette_score :" , silho_score)
# Out:
# silhouette_score : 0.616482075428874

# %%
color = np.array(['red','orange','green'])
sns.scatterplot(x=principle_df.pca1, y=principle_df.pca2, c=color[kmeans.labels_]) # Pass x and y as keyword arguments
plt.show()

# %% [markdown]
# # Trying with different model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
# Select features
x = data[['age', 'pace', 'shooting', 'passing', 'dribbling', 'defending']]
y = data['overall']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Linear Regression Model

# %%
model1 = LinearRegression()
model1.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model1.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R2 Score:", r2)
# Out:
# Mean Squared Error: 0.0076873473295278215
# R2 Score: 0.6517056122788425

# %% [markdown]
# ## Support Vector model

# %%
models = {
    'Support Vector Machine': SVR(kernel='rbf')
}

# %%
from sklearn.metrics import mean_squared_error, r2_score
results = {}
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    results[name] = (mse, r2)

# %%
print(f"Model: {name}")
print(f"MSE: {mse:.2f}")
print(f"R2 Score: {r2:.2f}")
print()
# Out:
# Model: Support Vector Machine
# MSE: 0.00
# R2 Score: 0.94

# %% [markdown]
# * From the above we show that linear regression, support vector machaine, kmeans  linear regression regression doesn't perform well for the above task but the SVM perform very well.
#
# * But Kmeans is suitable for identifying player groups/clusters, but not for regression tasks

# %% [markdown]
# ## Challenge Faced

# %% [markdown]
# * We have to delicatly handle the dataset because it have lot of feature more than 200 .
# * We have decide the important feature from that , domain analysis takes much more time to do.
# * dataset contain special characters so first we have remove them all then work on it.
# * While working on decision tree, its takes too much time to show the result.
